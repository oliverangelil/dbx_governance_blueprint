# %%
from pyspark.sql import Row

data = [
    Row(id=1, name="Alice", age=30),
    Row(id=2, name="Bob", age=25),
    Row(id=3, name="Charlie", age=35)
]

dummy_df = spark.createDataFrame(data)
#display(dummy_df)

dummy_df.write.saveAsTable("feature_branch_oliver.default.dummy_df")

# %%
# %sql
SHOW USERS

# %%
# %sql
SHOW GRANTS `oliver@ishango.ai` ON METASTORE

# %%
# %sql
GRANT USE RECIPIENT ON METASTORE TO `oliver@ishango.ai`;

# %%
# %sql
SHOW GRANTS ON METASTORE
